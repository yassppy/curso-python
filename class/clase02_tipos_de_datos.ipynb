# %% [markdown]
# # Tipos de datos
#
# Cada objeto en memoria tiene su propio tipo de dato definido desde que se crea.

# %% [markdown]
# ## Tipo de dato: Texto

# %% [markdown]
# Es un objeto de la clase `str` que representa una secuencia ordenada
# de caracteres, donde cada carácter tiene una posición llamada índice.
# Es **inmutable**, lo que significa que una vez creado el objeto en memoria,
# no puede ser modificado.

# %%
# Sencuencia de caracteres
nombre_curso = "Python"

# Acceder a la posición del índice del caracter individual
print(nombre_curso[0])
print(nombre_curso[1])
print(nombre_curso[2])
print(nombre_curso[3])
print(nombre_curso[4])
print(nombre_curso[5])
# Out:
# P
# y
# t
# h
# o
# n

# %% [markdown]
# > Python aplica la distinción entre mayúsculas y minúsculas (case-sensitive) en absolutamente todas las comparaciones de texto.

# %%
name = "Python"
# Operador ternario para escribir código
# Sintaxis: [valor_si_verdadero] if [condicion] else [valor_si_falso]
result = "Es igual" if name == "python" else "No es igual"
print(result)
# Out:
# No es igual

# %% [markdown]
# Todo texto es numérico y Python lo almacena en memoria usando Unicode (el cual ya incluye a ASCII para las letras básicas y añade caracteres como tildes, la ñ y emojis).

# %%
# Obtener el número de cada letra
print(f'obtener: {ord("e")} - convertir: {chr(101)}')
print(f'obtener: {ord("E")} - convertir: {chr(69)}')
# Out:
# obtener: 101 - convertir: e
# obtener: 69 - convertir: E

# %% [markdown]
# ### Como funciona los índices en la cádena

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - slicing: Extraer partes especificas
# - sintaxis: `variable[inicio:fin]` Toma desde la posición inicio HASTA ANTES de la posición fin (el fin quedar excluido)

# %%
frase = 'Hola'
print(frase[0])    # H → primer carácter desde la izquierda
print(frase[0:4])  # Hola → desde posición 0 hasta antes de la 4
print(frase[-4])   # H → primer carácter desde la derecha
print(frase[:])    # Hola → toda la cadena
# Out:
# H
# Hola
# H
# Hola

# %% [markdown]
# ### Métodos
#
# Al ser un objeto de la clase `str`, tiene sus propios métodos incluidos:
#
# - `.upper()` → convierte el texto a mayúsculas
# - `.lower()` → convierte el texto a minúsculas
# - `.strip()` → elimina espacios al inicio y al final
# - `.replace()` → reemplaza un texto por otro

# %%
nombre_curso = "Rust"
print(nombre_curso)
nombre_curso.upper() ## Se crea en memoria pero si no se hace referencia se pierde
nombre_curso = nombre_curso.upper()
print(nombre_curso)
# Out:
# Rust
# RUST

# %% [markdown]
# ### literales de string
#
# Distintas formas de crear un objeto String, puedes poner comillas dobles " " o comillas simples ' '. El que más se utiliza para hacer combinaciones es el f-string.

# %%
nombre = "Pedro"
edad = 30

# Concatenación de String unir 2 o más string
mensaje = f'Hola soy {nombre} y tengo {edad} años.'
print(mensaje)
# Out:
# Hola soy Pedro y tengo 30 años.

# %% [markdown]
# ### Docstrings
#
# Se coloca justo después de definir un módulo, función o clase la forma de documentar en PEP8.

# %%
"""
Este módulo contiene las funciones principales
del sistema de facturación.
"""

a = 12

# %% [markdown]
# ### Google Python Style Guide

# %% [markdown]
# - El estilo de Google sirve para documentar cualquier estructura principal de tu código. referencia https://google.github.io/styleguide/pyguide.html
# - A diferencia del docstring corto que tenías, el estilo de Google organiza la información en secciones claras usando encabezados como Args (argumentos), Returns (lo que retorna) y Raises (si lanza algún error).

# %%
# Funciones

def calcular_total_factura(precio_unitario: float, cantidad: int) -> float:
    """Calcula el monto total a pagar

    Multiplica el precio unitario por la cantidad para obtener el subtotal y
    luego aplicar el IGV

    Args:
        precio_unitario (float): El precio de un solo producto antes de impuestos.
        cantidad (int): El número de unidades compradas.

    Returns:
        float: El monto total final a pagar con el 18% de IGV incluido.
    """
    subtotal = precio_unitario * cantidad
    igv = subtotal * 0.18
    total = subtotal + igv
    return total


total_a_pagar = calcular_total_factura(precio_unitario=100.0, cantidad=3)
print(f"Total a pagar: S/ {total_a_pagar:.2f}")
# Out:
# Total a pagar: S/ 354.00

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Tipo de dato: Números

# %% [markdown]
# Recordando que se hace una referencia del objeto ya sea (int o float) en memoria y de igual forma son inmutables

# %% [markdown]
# **int**: Números enteros sin decimales.

# %%
edad = 25
print(type(edad))
# Out:
# <class 'int'>

# %% [markdown]
# **números complejos**: Un número complejo es la combinación de una parte real y una parte imaginaria.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
complex_num= 3.4j
print(type(complex_num))
# Out:
# <class 'complex'>

# %% [markdown]
# **float**: Números con decimales. Esto siguen el estándar de IEEE 745 que tiene una precisión limitada de 15 a 17 dígitos.

# %%
from decimal import Decimal

precio = 3.14
print(type(precio))

## Precisión limitada

print(0.1+0.2) ## algunos dedimales no tiene representación exacta en binario

## Utilizando un paquete para precisión exacta deben estar en comillas

sum = Decimal("0.1")+Decimal("0.2")
print(f"Resultado: {sum:.2f}")
print(type(sum))
# Out:
# <class 'float'>
# 0.30000000000000004
# Resultado: 0.30
# <class 'decimal.Decimal'>

# %% [markdown]
# ### Separadores numéricos con `_`
#
# Se usa el guion bajo (`_`) para separar visualmente números largos
# y mejorar la legibilidad del código. Python ignora los `_` internamente,
# el valor almacenado en memoria es el mismo.

# %%
poblacion = 1_000_000      # igual a 1000000
precio = 1_234_567.89      # igual a 1234567.89

print(poblacion)
print(type(poblacion))
# Out:
# 1000000
# <class 'int'>

# %% [markdown]
# ### Multilpe Assignment
# Asigna valores a varias variables en una sola línea. Python lee primero
# el lado derecho, crea los objetos en memoria y luego asigna cada etiqueta
# a su valor correspondiente por posición. Internamente usa tuplas para
# empaquetar y desempaquetar los valores.
#
# **Sintaxis:**
# ```python
# a, b = valor_a, valor_b

# %%
a, b = 10, 20

print(f'El valor de a es {a} y b es {b}')
# Out:
# El valor de a es 10 y b es 20

# %%
# Asignar el valor a varias variables a la vez
a = b = c = 2
print(a)
print(b)
print(c)
# Out:
# 2
# 2
# 2

# %%
# intercambiar valores
a = 200
b = 100

a,b = b,a
print(a)
print(b)
# Out:
# 100
# 200

# %%
# Tupla como se ve

tupla_valores = 10, 20, 30
print(type(tupla_valores))
# Out:
# <class 'tuple'>

# %% [markdown]
# ## Tipo de dato: Booleano

# %%
# Representa verdadero o falso
status = True

print(status)
print(type(status))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# ## Tipo de dato: Colecciones

# %% [markdown]
# ### Listas

# %% [markdown]
# Es un tipo de dato compuesto que agrupa múltiples valores bajo una misma
# etiqueta. Es **mutable**, lo que significa que sus elementos pueden
# modificarse, agregarse o eliminarse sin crear un nuevo objeto en memoria.

# %%
# ✅ Lista homogénea → recomendado
list_num = [1, 2, 3]
list_text = ["Miguel", "Pedro", "Luis"]
# ⚠️ Lista mixta → no recomendado mejor tupla
list_mix = [1, "Miguel", True]

print(type(list_num))
print(list_num)
print(list_text)
print(list_mix)
# Out:
# <class 'list'>
# [1, 2, 3]
# ['Miguel', 'Pedro', 'Luis']
# [1, 'Miguel', True]

# %%
list_text[0]
# Out:
# 'Miguel'

# %% [markdown]
# Vemos como funciona internamente una lista en memoria:
#  - **append** → agrega un solo elemento al final de la lista
#  - **extend** → agrega los elementos de otra lista uno por uno al final

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
estudiantes = ["Juan", "Pedro", "Miguel"]
print(estudiantes)
print(f'Referencia principal: {id(estudiantes)}')
print(f'Referencia del elemento 0: {id(estudiantes[0])}')
print(f'Referencia del elemento 1: {id(estudiantes[1])}')
print(f'Referencia del elemento 2: {id(estudiantes[2])}')

# Cambiamos el elmento 0 por otro
estudiantes[0] = "Anita"
print(estudiantes)
print(f'Referencia principal: {id(estudiantes)}')
print(f'Referencia del elemento 0: {id(estudiantes[0])}')

# Agregar el elemento

estudiantes.append("Alejandro")
print(estudiantes)

estudiantes.extend(["Alexis","Mauro"])
print(estudiantes)
# Out:
# ['Juan', 'Pedro', 'Miguel']
# Referencia principal: 2095103480576
# Referencia del elemento 0: 2095103180944
# Referencia del elemento 1: 2095103185216
# Referencia del elemento 2: 2095103190304
# ['Anita', 'Pedro', 'Miguel']
# Referencia principal: 2095103480576
# Referencia del elemento 0: 2095103310944
# ['Anita', 'Pedro', 'Miguel', 'Alejandro']
# ['Anita', 'Pedro', 'Miguel', 'Alejandro', 'Alexis', 'Mauro']

# %% [markdown]
# ### Tupla

# %% [markdown]
# Es un tipo de dato compuesto inmutable y ordenada que agrupa múltiples valores en ( ) bajo una misma etiqueta. Al ser inmutable, una vez creada en memoria no puede modificarse.

# %%
# Crear una tupla para estudiantes quiero guardar el id_estudiante, nombre, edad
tupla_estudiantes = (1, "Juan", 30)
print(tupla_estudiantes)
print(type(tupla_estudiantes))
# Out:
# (1, 'Juan', 30)
# <class 'tuple'>

# %% [markdown]
# ### Diccionario

# %% [markdown]
# Es un tipo de dato compuesto mutable que almacena pares de clave-valor. A diferencia de la lista que usa índices numéricos, el diccionario usa claves para acceder a cada valor.
#
# - El método `.get()` permite especificar un valor por defecto en caso de que no exista esa clave y no tener un error.
# - El método `.pot()` elimina elementos.
# - El método `.keys()` va a mostrar solamente las claves.
# - El método `.values()` va a mostrar solamente los valores.

# %%
personas = {
    "nombre":"Miguel",
    "edad":32,
    #"ciudad":"Lima"
}

# Accerder a cada valor
print(personas["nombre"])
print(personas["edad"])
print(personas.get("ciudad", "No existe"))

# Agregar o modificar
personas["email"] = "mg@gmail.com"
personas["edad"] = 45

print(personas["email"])
print(personas["edad"])

# Eliminar
personas.pop("email")

# ver claves o valores
print(personas.keys())
print(personas.values())
print(personas.items())

# Recorrer

for clave, valor in personas.items():
    print(f'{clave}: {valor}')
# Out:
# Miguel
# 32
# No existe
# mg@gmail.com
# 45
# dict_keys(['nombre', 'edad'])
# dict_values(['Miguel', 45])
# dict_items([('nombre', 'Miguel'), ('edad', 45)])
# nombre: Miguel
# edad: 45

# %% [markdown]
# - **Slice** no es función ni método, es una sintaxis propia de Python que funciona en cualquier secuencia:
# - Regla clave: el fin nunca se incluye por eso se le aumenta uno, igual que range().
# - sintaxis: `secuencia[inicio:fin:paso]` cada parte es opcional

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
message = "Hola Mundo"
print(message[0:4:1])
print(message[:4])
# Out:
# Hola
# Hola

# %%
numeros = [0, 1, 2, 3, 4, 5]
#índices:   0  1  2  3  4  5

print(numeros[1:4])    # → [1, 2, 3]      desde índice 1 hasta 4 (sin incluir)
print(numeros[::2])   # → [0, 2, 4]      de 2 en 2
print(numeros[::-1])   # → [5, 4, 3, 2, 1, 0]  invertido
print(numeros[2:])   # → [2, 3, 4, 5]   desde índice 2 hasta el final
print(numeros[:3])   # → [0, 1, 2]      desde el inicio hasta índice 3 (sin incluir)
# Out:
# [1, 2, 3]
# [0, 2, 4]
# [5, 4, 3, 2, 1, 0]
# [2, 3, 4, 5]
# [0, 1, 2]
